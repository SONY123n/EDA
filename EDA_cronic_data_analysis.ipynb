# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings 
warnings.filterwarnings('ignore')
plt.style.use("fivethirtyeight")
# %matplotlib inline
pd.set_option('display.max_columns',30)

# %%
import os
os.path.exists(r"C:\Users\jarup\Downloads\data science papers\EDA\kidney_disease.csv")
# Out:
# True

# %%
df=pd.read_csv(r"C:\Users\jarup\Downloads\data science papers\EDA\kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba    bgr    bu   sc    sod  pot  hemo pcv    wc   rc  htn   dm  \
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.size
# Out:
# 10400

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.id
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 395    395
# 396    396
# 397    397
# 398    398
# 399    399
# Name: id, Length: 400, dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
df
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             330 non-null    object
#  16  wc              295 non-null    object
# ...

# %%
df['pcv']#this is the string type now we need the str into int
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: pcv, Length: 400, dtype: object

# %%
df[ 'pcv']=pd.to_numeric(df['pcv'],errors='coerce')#error coerce do that if any null value is there then it will try noit to convert it

# %%
df['pcv']
# Out:
# 0      44.0
# 1      38.0
# 2      31.0
# 3      32.0
# 4      35.0
#        ...
# 395    47.0
# 396    54.0
# 397    49.0
# 398    51.0
# 399    53.0
# Name: pcv, Length: 400, dtype: float64

# %%
#df['wc']=df['wc'].astype(float,errors='ignore')

# %%
df['wc']
# Out:
# 0      7800
# 1      6000
# 2      7500
# 3      6700
# 4      7300
#        ...
# 395    6700
# 396    7800
# 397    6600
# 398    7200
# 399    6800
# Name: wc, Length: 400, dtype: object

# %%
df[ 'wc']=pd.to_numeric(df['wc'],errors='coerce')

# %%
df['wc']
# Out:
# 0      7800.0
# 1      6000.0
# 2      7500.0
# 3      6700.0
# 4      7300.0
#         ...
# 395    6700.0
# 396    7800.0
# 397    6600.0
# 398    7200.0
# 399    6800.0
# Name: wc, Length: 400, dtype: float64

# %%
df[ 'rc']=pd.to_numeric(df['rc'],errors='coerce')

# %%
df['rc']
# Out:
# 0      5.2
# 1      NaN
# 2      NaN
# 3      3.9
# 4      4.6
#       ...
# 395    4.9
# 396    6.2
# 397    5.4
# 398    5.9
# 399    6.1
# Name: rc, Length: 400, dtype: float64

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                float64
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
#separating the data as objects and floats

cat_cols=[ col for col in df.columns if df[col].dtype=='object']
nums_cols=[ col for col in df.columns if df[col].dtype!='object']

# %%
cat_cols
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
nums_cols
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values.\n")
# Out:
# rbc has [nan 'normal' 'abnormal'] values.
#
# pc has ['normal' 'abnormal' nan] values.
#
# pcc has ['notpresent' 'present' nan] values.
#
# ba has ['notpresent' 'present' nan] values.
#
# htn has ['yes' 'no' nan] values.
#
# dm has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values.
#
# cad has ['no' 'yes' '\tno' nan] values.
#
# appet has ['good' 'poor' nan] values.
#
# pe has ['no' 'yes' nan] values.
#
# ane has ['no' 'yes' nan] values.
#
# classification has ['ckd' 'ckd\t' 'notckd'] values.

# %%
df['dm'].replace(to_replace={'\tno' : 'no','\tyes':'yes','yes':'yes'},inplace=True)

# %%
df['cad']=df['cad'].replace(to_replace='\tno', value= "no",inplace=True)

# %%
df['cad'].unique()
# Out:
# array([None], dtype=object)

# %%
df['classification']
# Out:
# 0         ckd
# 1         ckd
# 2         ckd
# 3         ckd
# 4         ckd
#         ...
# 395    notckd
# 396    notckd
# 397    notckd
# 398    notckd
# 399    notckd
# Name: classification, Length: 400, dtype: object

# %%
df['classification'].replace(to_replace={'ckd\t' : 'ckd','notckd':'not ckd'},inplace=True)

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'not ckd'], dtype=object)

# %%
#now to convert the df classification in to integer

# %%
df['classification']=df['classification'].map({'ckd' : 0,'not ckd':1})

# %%
df['classification']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: classification, Length: 400, dtype: int64

# %%
df['age']
# Out:
# 0      48.0
# 1       7.0
# 2      62.0
# 3      48.0
# 4      51.0
#        ...
# 395    55.0
# 396    42.0
# 397    12.0
# 398    17.0
# 399    58.0
# Name: age, Length: 400, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              294 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                71
# wc                106
# rc                131
# htn                 2
# dm                  2
# cad               400
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
#univariate analysis
plt.figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde=True,color='m')
plt.title("distribution od age")
plt.xlabel('age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#insights
# the mean age is around 50
#most of the people are around 40-60
#70-80 age having low people
#

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.htn
# Out:
# 0      yes
# 1       no
# 2       no
# 3      yes
# 4       no
#       ...
# 395     no
# 396     no
# 397     no
# 398     no
# 399     no
# Name: htn, Length: 400, dtype: object

# %%
df['htn'].value_counts()
# Out:
# htn
# no     251
# yes    147
# Name: count, dtype: int64

# %%
#how many people having cronic disease ha hypertesion
plt.figure(figsize=(10,6))
sns.countplot(x='htn',data =df,palette='viridis')
plt.title("count of hyper tension")
plt.xlabel('hyper tension')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
#150 people around having hyper tension

# %%
#making a box plot
plt.figure(figsize=(10,6))
sns.boxplot(x='classification',y='bu',data=df)
plt.xlabel('classification')
plt.ylabel('blood urea')
plt.title("boxplot of blood urea by class")
# Out:
# Text(0.5, 1.0, 'boxplot of blood urea by class')

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='classification',y='sc',data=df)
plt.xlabel('classification')
plt.ylabel('serum creatinine')
plt.title("violinplot of serum creatinine by class")
# Out:
# Text(0.5, 1.0, 'violinplot of serum creatinine by class')

# %%
sns.countplot(x='ane',data=df)
# Out:
# <Axes: xlabel='ane', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.appet
# Out:
# 0      good
# 1      good
# 2      poor
# 3      poor
# 4      good
#        ...
# 395    good
# 396    good
# 397    good
# 398    good
# 399    good
# Name: appet, Length: 400, dtype: object

# %%
df['appet'].value_counts().plot.pie(autopct='%1.1f%%',explode=(0,0.1),startangle=90)
# Out:
# <Axes: ylabel='count'>

# %%
df['appet'].value_counts().plot.pie(autopct='%1.1f%%',wedgeprops=dict(width=0.3))#wedgeprops will give us the donut shape pie chart
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x='pe',data=df)
# Out:
# <Axes: xlabel='pe', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
plotnumber=1

for col in nums_cols:
    if plotnumber<=15:
        ax=plt.subplot(3,5,plotnumber)
        sns.distplot(df[col])
        plt.xlabel(col)
    plotnumber +=1

plt.tight_layout()
plt.show()

# %%
df.dtypes
# Out:
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                float64
# rc                float64
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification      int64
# dtype: object

# %%
def kde(col):
    grid=sns.FacetGrid(df,hue='classification',height=6,aspect=2)
    grid.map(sns.kdeplot,col)
    grid.add_legend()

# %%
kde('rc')

# %%
kde('wc')

# %%
def  violin(col):
    fig=px.violin(df,y=col,x="classification",box=True,template='plotly_dark')
    return fig.show()

# %%
violin('hemo')

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
violin('age')

# %%
#violin('specific_gravity')

# %%
#two variables plotting
#bivariate
sns.scatterplot(x='age',y='bp',data=df,hue='classification')
# Out:
# <Axes: xlabel='age', ylabel='bp'>

# %%
#insights >>>
#high bp causes chronic disease

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
diabeter_hypertension=pd.crosstab(df['dm'],df['htn'])
diabeter_hypertension.plot(kind='bar',stacked=True,color=['#6DA7DE','#FF9A88'],figsize=(10,6))
plt.xlabel('diabeter_mellitus and hypertension')
plt.ylabel('count')
plt.legend(title='hypertension')
plt.title('stacked diabeter_mellitus and hypertension')
plt.show()

# %%
diabeter_hypertension
# Out:
# htn    no  yes
# dm
#  yes    0    1
# no    220   41
# yes    31  105

# %%
def scatter(col1,col2):
    fig=px.scatter(df,x=col1,y=col2,color='classification',template='plotly_dark')
    return fig.show()

# %%
scatter('hemo','pcv')

# %%
#multivariable analysis

selected_columns=['age','hemo','bp','classification']
sns.pairplot(df[selected_columns],hue="classification",palette='husl')

# %%
#heat map
df[selected_columns].corr()#corr means corelation
sns.heatmap(df[selected_columns].corr(),annot=True,cmap='coolwarm',linewidth=.5)
# Out:
# <Axes: >

# %%
import plotly.graph_objects as go
heatmap_data=df[selected_columns].corr()

fig =go.Figure(data=go.Heatmap(z=heatmap_data.values,
                               x=heatmap_data.columns,
                               y=heatmap_data.index,
                               colorscale='viridis'))

fig.update_layout(title='interactive heatmap of correlation matrix')
fig.show()
