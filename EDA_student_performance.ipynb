# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os 
os.path.exists(r"C:\Users\jarup\Downloads\data science papers\EDA\student-por.csv")
# Out:
# True

# %%
df=pd.read_csv(r"C:\Users\jarup\Downloads\data science papers\EDA\student-por.csv")

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.shape
# Out:
# (649, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
#what are the count of students for each school

sns.countplot(x='school',data=df,palette='pastel')
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_8348\227633768.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='school',data=df,palette='pastel')
# <Axes: xlabel='school', ylabel='count'>

# %%
sns.pie(df['school'].value_counts(), autopct="%1.1f%%")  # Display percentages with one decimal place
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 sns.pie(df['school'].value_counts(), autopct="%1.1f%%")  # Display percentages with one decimal place
#       2 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'pie'

# %%
df.age.value_counts()
# Out:
# age
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: count, dtype: int64

# %%
sns.histplot(df.age,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address
# Out:
# 0      U
# 1      U
# 2      U
# 3      U
# 4      U
#       ..
# 644    R
# 645    U
# 646    U
# 647    U
# 648    R
# Name: address, Length: 649, dtype: object

# %%
df.address.unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x='address',data=df,palette='dark')
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_8348\387230500.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='address',data=df,palette='dark')
# <Axes: xlabel='address', ylabel='count'>

# %%
df.reason.unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
reason_counts=df.reason.value_counts()

# %%
df.reason
# Out:
# 0      course
# 1      course
# 2       other
# 3        home
# 4        home
#         ...
# 644    course
# 645    course
# 646    course
# 647    course
# 648    course
# Name: reason, Length: 649, dtype: object

# %%
plt.pie(reason_counts,labels=reason_counts.index,autopct="%1.1f%%")
plt.show()

# %%
df['activities'].value_counts()
# Out:
# activities
# no     334
# yes    315
# Name: count, dtype: int64

# %%
wac=df['Walc'].value_counts()

# %%
plt.pie(wac,labels=wac.index,autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1de73cd2510>,
# ...
#  [Text(0.4030549984700621, 1.0234972731806853, '1'),
#   Text(-1.0996778255423472, 0.02662104450346281, '2'),
#   Text(-0.31245939664709116, -1.05468911317361, '3'),
#   Text(0.7203468250294088, -0.8313245164615624, '4'),
#   Text(1.0740055804868376, -0.2377225548473076, '5')],
#  [Text(0.2198481809836702, 0.5582712399167374, '38.1%'),
#   Text(-0.5998242684776438, 0.01452056972916153, '23.1%'),
#   Text(-0.17043239817114061, -0.575284970821969, '18.5%'),
#   Text(0.39291645001604114, -0.4534497362517612, '13.4%'),
#   Text(0.5858212257200932, -0.1296668480985314, '6.9%')])

# %%
df.freetime.value_counts()
# Out:
# freetime
# 3    251
# 4    178
# 2    107
# 5     68
# 1     45
# Name: count, dtype: int64

# %%
sns.boxplot(df.freetime)
# Out:
# <Axes: ylabel='freetime'>

# %%
sns.scatterplot(df.freetime)
# Out:
# <Axes: ylabel='freetime'>

# %%
sns.boxplot(df.Dalc)
# Out:
# <Axes: ylabel='Dalc'>

# %%
sns.histplot(df.studytime)
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
sns.histplot(df.Dalc)
# Out:
# <Axes: xlabel='Dalc', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.Medu
# Out:
# 0      4
# 1      1
# 2      1
# 3      4
# 4      3
#       ..
# 644    2
# 645    3
# 646    1
# 647    3
# 648    3
# Name: Medu, Length: 649, dtype: int64

# %%
sns.histplot(df.Medu)
# Out:
# <Axes: xlabel='Medu', ylabel='Count'>

# %%
df.Pstatus.unique()#A - away
and T- living together
# Out:
# array(['A', 'T'], dtype=object)

# %%
sns.boxplot(data=df,x="Pstatus",y="absences")
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
sns.scatterplot(data=df,x="Pstatus",y="absences")
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
sns.barplot(data=df,x="Pstatus",y="absences")
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
df.sex.value_counts()
# Out:
# sex
# F    383
# M    266
# Name: count, dtype: int64

# %%
counts=df.Fjob.value_counts()
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Fjob'>

# %%
counts=df.Mjob.value_counts()
counts.plot(kind='bar')
# Out:
# <Axes: xlabel='Mjob'>

# %%
df.hist(bins=100,figsize=(30,40))#bins means number of interval are required
plt.show()

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: count, dtype: int64

# %%
sns.barplot(df.G1.value_counts())
# Out:
# <Axes: xlabel='G1', ylabel='count'>

# %%
sns.countplot(df,x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
#do urban students score higher than rural student?
sns.kdeplot(df.loc[df['address']=='U','G1'],label="Urban",shade=True)
sns.kdeplot(df.loc[df['address']=='R','G1'],label="Rural",shade=True)
plt.title("performance comparison for G1")
plt.xlabel("grade 1")
plt.show()
# Out:
# C:\Users\jarup\AppData\Local\Temp\ipykernel_16284\879918529.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='U','G1'],label="Urban",shade=True)
# C:\Users\jarup\AppData\Local\Temp\ipykernel_16284\879918529.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']=='R','G1'],label="Rural",shade=True)
