# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings 
warnings.filterwarnings('ignore')
plt.style.use("fivethirtyeight")
# %matplotlib inline
pd.set_option('display.max_columns',30)

# %%
import os
os.path.exists(r"C:\Users\jarup\Downloads\data science papers\EDA\us_perm_visas.csv")
# Out:
# True

# %%
df=pd.read_csv(r"C:\Users\jarup\Downloads\data science papers\EDA\us_perm_visas.csv")

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374357                         NaN   Buena Park
# 374358                         NaN      Seattle
# 374359                         NaN   Schaumburg
# 374360                         NaN  LOS ANGELES
# 374361                         NaN      Phoenix
#
#                                           agent_firm_name agent_state  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      332168
# agent_city                       162908
# agent_firm_name                  167365
# agent_state                      166123
# application_type                 239093
#                                   ...
# wage_offer_to_9089               300728
# wage_offer_unit_of_pay_9089      115916
# wage_offered_from_9089           259715
# wage_offered_to_9089             343347
# wage_offered_unit_of_pay_9089    303663
# Length: 154, dtype: int64

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089       object
# agent_city                        object
# agent_firm_name                   object
# agent_state                       object
# application_type                  object
#                                   ...
# wage_offer_to_9089                object
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089     object
# Length: 154, dtype: object

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.size
# Out:
# 57651748

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Columns: 154 entries, add_these_pw_job_title_9089 to wage_offered_unit_of_pay_9089
# dtypes: float64(10), object(144)
# memory usage: 439.8+ MB

# %%
df.describe()
# Out:
#        employer_num_employees  employer_yr_estab  \
# count            2.390130e+05      238958.000000
# mean             2.309387e+04        1984.208267
# std              5.453129e+05          38.470555
# min              0.000000e+00           0.000000
# 25%              7.300000e+01        1980.000000
# 50%              1.200000e+03        1996.000000
# 75%              1.613400e+04        2004.000000
# max              2.635506e+08        2016.000000
#
#        foreign_worker_yr_rel_edu_completed  fw_info_yr_rel_edu_completed  \
# count                         83364.000000                 137198.000000
# mean                           2001.345761                   2002.633603
# std                              91.444715                     89.674423
# min                               0.000000                      0.000000
# 25%                            2003.000000                   2004.000000
# 50%                            2006.000000                   2007.000000
# ...

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df['case_number']
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 374357    A-16363-85407
# 374358    A-16271-56745
# 374359    A-16354-82345
# 374360    A-16357-84250
# 374361    A-16279-59292
# Name: case_number, Length: 374362, dtype: object

# %%
df['case_no']
# Out:
# 0         A-07323-97014
# 1         A-07332-99439
# 2         A-07333-99643
# 3         A-07339-01930
# 4         A-07345-03565
#               ...
# 374357              NaN
# 374358              NaN
# 374359              NaN
# 374360              NaN
# 374361              NaN
# Name: case_no, Length: 374362, dtype: object

# %%
df.drop('case_number',axis=1,inplace=True)

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        'country_of_citzenship', 'decision_date', 'employer_address_1',
#        'employer_address_2', 'employer_city', 'employer_country',
#        'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df.case_status
# Out:
# 0         Certified
# 1            Denied
# 2         Certified
# 3         Certified
# 4         Certified
#             ...
# 374357    Withdrawn
# 374358    Withdrawn
# 374359    Withdrawn
# 374360    Withdrawn
# 374361    Withdrawn
# Name: case_status, Length: 374362, dtype: object

# %%
df=df[df['case_status']!='withdrawn']#withdraw application that doesn't make much sense ,so this application should not be analysed

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'certified', 'Withdrawn'], dtype=object)

# %%
df.loc[df.case_status=='Certified-Expired','case_status']='certified'

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'certified', 'Withdrawn'], dtype=object)

# %%
df.case_status.value_counts(normalize=True)
# Out:
# case_status
# Certified    0.485981
# certified    0.396905
# Denied       0.068514
# Withdrawn    0.048600
# Name: proportion, dtype: float64

# %%
#insights>>
#only 7% people were denied

# %%
#dropping the null values

# %%
df.dropna(axis=1,how='all',inplace=True)#drop the columns which hava all the values null

# %%
df.dropna(axis=0,how='all',inplace=True)

# %%
df.shape
# Out:
# (374362, 153)

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=153)

# %%
df.application_type
# Out:
# 0         PERM
# 1         PERM
# 2         PERM
# 3         PERM
# 4         PERM
#           ...
# 374357     NaN
# 374358     NaN
# 374359     NaN
# 374360     NaN
# 374361     NaN
# Name: application_type, Length: 374362, dtype: object

# %%
df['application_type'].value_counts().plot(kind='bar',color='#fc419a')
# Out:
# <Axes: xlabel='application_type'>

# %%
#insight is >> most people are applied through online

# %%
sns.countplot(data=df,x='application_type',color='#a33c6a')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
df.us_economic_sector
# Out:
# 0                            IT
# 1         Other Economic Sector
# 2                     Aerospace
# 3         Other Economic Sector
# 4                  Advanced Mfg
#                   ...
# 374357                      NaN
# 374358                      NaN
# 374359                      NaN
# 374360                      NaN
# 374361                      NaN
# Name: us_economic_sector, Length: 374362, dtype: object

# %%
economic_sector=df['us_economic_sector'].value_counts()

# %%
economic_sector
# Out:
# us_economic_sector
# IT                       52617
# Advanced Mfg             18749
# Other Economic Sector    15798
# Finance                   9224
# Educational Services      9130
# Health Care               6825
# Retail                    4408
# Aerospace                 4166
# Hospitality               1926
# Construction              1409
# Automotive                1163
# Energy                    1086
# Transportation             949
# Agribusiness               939
# Biotechnology              456
# Geospatial                 141
# Homeland Security           82
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,20))
plt.pie(economic_sector,labels=economic_sector.index,autopct='%1.1f%%')
plt.show()

# %%
#you will get us viva IT

# %%
df['decision_date']=pd.to_datetime(df['decision_date'])

df['year']=df['decision_date'].dt.year

# %%
df['year']
# Out:
# 0         2012
# 1         2011
# 2         2011
# 3         2011
# 4         2012
#           ...
# 374357    2016
# 374358    2016
# 374359    2016
# 374360    2016
# 374361    2016
# Name: year, Length: 374362, dtype: int32

# %%
fig,ax=plt.subplots(figsize=(10,8))

sns.countplot(x='year',hue='case_status',data=df)
ax.set(xlabel='visa application year',ylabel='no.of applications')
plt.show()

# %%
#insights as applications increase ,denied and accepted both increasing

# %%
fig,ax=plt.subplots(figsize=(10,8))

sns.countplot(x='employer_city',hue='year',data=df,order=df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel='employe city',ylabel='year')

plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,8))

sns.countplot(x='employer_city',hue='year',data=df,order=df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel='employe city',ylabel='number of applications')
plt.xticks(rotation=90)#this will rotate the names on the x axis ,so that the names will appear clear
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,8))

sns.countplot(x='employer_city',hue='year',data=df,order=df.employer_city.value_counts().iloc[:20].index)
ax.set(xlabel='employe city',ylabel='number of applications')

plt.xticks(rotation=90)#this will rotate the names on the x axis ,so that the names will appear clear
plt.show()
